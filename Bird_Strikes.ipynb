# %% [markdown]
# # Data Visualization of Bird Strikes between 2000 – 2011 Analysis
#
# DATA GHATHERING
# Introduction:Data visualization of bird strikes between 2000-2011 provides a graphical representation of the frequency, location, and impact of bird strikes on aircraft during that period. Through charts, graphs, and maps, it illustrates trends, patterns, and hotspots, aiding in understanding the dynamics of bird strikes and informing preventive measures for aviation safety.
#
# Problem Statement:The problem statement highlights the critical role of transport and communication in analytics, particularly addressing environmental impacts, safety concerns, and the increasing bird strike incidents in aviation. It emphasizes the need for innovative solutions, including the use of technologies like Multi-Agent Systems (MAS), to address these challenges effectively. The document also provides insight into the FAA data collected on bird strikes between 2000-2011, underscoring the significance of mitigating this threat to aircraft safety.

# %%
from warnings import filterwarnings
filterwarnings('ignore')

import os
os.chdir('D:/py/')

import numpy as np
import pandas as pd 

from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns

# %%
import os
os.chdir('D:/py/')

# %%
# Assuming the dataset is in a CSV file
bird_strikes=pd.read_csv("Bird Strikes data.xlsx - Bird Strikes.csv")
bird_strikes
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %% [markdown]
# # EDA

# %%
# Display basic information about the dataset
bird_strikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25429 non-null  object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
bird_strikes.corr()
# Out:
#                                          Record ID  \
# Record ID                                 1.000000
# Wildlife: Number Struck Actual           -0.025016
# Remains of wildlife collected?            0.260331
# Remains of wildlife sent to Smithsonian   0.135498
# Number of people injured                 -0.006210
#
#                                          Wildlife: Number Struck Actual  \
# Record ID                                                     -0.025016
# Wildlife: Number Struck Actual                                 1.000000
# Remains of wildlife collected?                                 0.038811
# Remains of wildlife sent to Smithsonian                        0.014890
# Number of people injured                                       0.010150
#
#                                          Remains of wildlife collected?  \
# Record ID                                                      0.260331
# Wildlife: Number Struck Actual                                 0.038811
# ...

# %%
bird_strikes.describe(include='all')
# Out:
#             Record ID Aircraft: Type                Airport: Name  \
# count    25558.000000          25429                        25429
# unique            NaN              1                         1109
# top               NaN       Airplane  DALLAS/FORT WORTH INTL ARPT
# freq              NaN          25429                          803
# mean    253916.085609            NaN                          NaN
# std      38510.453382            NaN                          NaN
# min       1195.000000            NaN                          NaN
# 25%     225783.750000            NaN                          NaN
# 50%     248749.000000            NaN                          NaN
# 75%     269168.750000            NaN                          NaN
# max     321909.000000            NaN                          NaN
#
#        Altitude bin Aircraft: Make/Model Wildlife: Number struck  \
# count         25429                25558                   25429
# ...

# %%
bird_strikes.isna().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                              129
# Airport: Name                               129
# Altitude bin                                129
# Aircraft: Make/Model                          0
# Wildlife: Number struck                     129
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                    129
# FlightDate                                  129
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                267
# Aircraft: Airline/Operator                  129
# Origin State                                449
# When: Phase of flight                       129
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4771
# Wildlife: Size                              129
# Conditions: Sky                               0
# ...

# %%
bird_strikes.shape
# Out:
# (25558, 26)

# %%
# Display the first few rows of the dataset
bird_strikes.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 0                             859         Engine Shut Down  11/23/00 0:00
# 1                             424                     None   7/25/01 0:00
# ...

# %%
bird_strikes.tail()
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 25553              EMB-120                       1
# 25554                A-321                       1
# 25555               EC-135                     NaN
# 25556            B-757-200                       1
# 25557            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 25553                               1                     None  12/30/11 0:00
# ...

# %% [markdown]
# 1. converted altitude:bin object dtypes to int dtypes in the csv file.
# 2. FlightDate is converted to date formate in csv.

# %%
bird_strikes.count()
# Out:
# Record ID                                  25558
# Aircraft: Type                             25429
# Airport: Name                              25429
# Altitude bin                               25429
# Aircraft: Make/Model                       25558
# Wildlife: Number struck                    25429
# Wildlife: Number Struck Actual             25558
# Effect: Impact to flight                   25429
# FlightDate                                 25429
# Effect: Indicated Damage                   25558
# Aircraft: Number of engines?               25291
# Aircraft: Airline/Operator                 25429
# Origin State                               25109
# When: Phase of flight                      25429
# Conditions: Precipitation                  25558
# Remains of wildlife collected?             25558
# Remains of wildlife sent to Smithsonian    25558
# Remarks                                    20787
# Wildlife: Size                             25429
# ...

# %%
bird_strikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25429 non-null  object
#  8   FlightDate                               25429 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
bird_strikes.dtypes
# Out:
# Record ID                                   int64
# Aircraft: Type                             object
# Airport: Name                              object
# Altitude bin                               object
# Aircraft: Make/Model                       object
# Wildlife: Number struck                    object
# Wildlife: Number Struck Actual              int64
# Effect: Impact to flight                   object
# FlightDate                                 object
# Effect: Indicated Damage                   object
# Aircraft: Number of engines?               object
# Aircraft: Airline/Operator                 object
# Origin State                               object
# When: Phase of flight                      object
# Conditions: Precipitation                  object
# Remains of wildlife collected?               bool
# Remains of wildlife sent to Smithsonian      bool
# Remarks                                    object
# Wildlife: Size                             object
# ...

# %%
sns.boxplot(x='Wildlife: Number struck',
            y='Number of people injured',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Wildlife: Number struck', ylabel='Number of people injured'>

# %%
sns.heatmap(bird_strikes.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plot1=pd.crosstab(bird_strikes['Aircraft: Number of engines?'],bird_strikes['Aircraft: Airline/Operator'])
plot1
# Out:
# Aircraft: Airline/Operator    ABSA AEROLINHAS BRASILEIRAS  ABX AIR  \
# Aircraft: Number of engines?
# 1                                                       0        0
# 2                                                       1      164
# 3                                                       0        0
# 4                                                       0       25
# C                                                       0        0
#
# Aircraft: Airline/Operator    ACM AVIATION  ADI SHUTTLE GROUP  AER LINGUS  \
# Aircraft: Number of engines?
# 1                                        0                  0           0
# 2                                        2                  8           7
# 3                                        0                  0           0
# 4                                        0                  0           0
# C                                        0                  0           0
#
# ...

# %%
sns.scatterplot(x='Wildlife: Number Struck Actual',y='Number of people injured', data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Wildlife: Number Struck Actual', ylabel='Number of people injured'>

# %%
bird_strikes.nunique()
# Out:
# Record ID                                  25558
# Aircraft: Type                                 1
# Airport: Name                               1109
# Altitude bin                                   2
# Aircraft: Make/Model                         351
# Wildlife: Number struck                        4
# Wildlife: Number Struck Actual               106
# Effect: Impact to flight                       5
# FlightDate                                  4225
# Effect: Indicated Damage                       2
# Aircraft: Number of engines?                   5
# Aircraft: Airline/Operator                   292
# Origin State                                  60
# When: Phase of flight                          7
# Conditions: Precipitation                      8
# Remains of wildlife collected?                 2
# Remains of wildlife sent to Smithsonian        2
# Remarks                                    18186
# Wildlife: Size                                 3
# ...

# %%
cat=[]
con=[]
for i in bird_strikes.columns:
    if bird_strikes[i].dtypes=='object':
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Aircraft: Type',
#  'Airport: Name',
#  'Altitude bin',
#  'Aircraft: Make/Model',
#  'Wildlife: Number struck',
#  'Effect: Impact to flight',
#  'FlightDate',
#  'Effect: Indicated Damage',
#  'Aircraft: Number of engines?',
#  'Aircraft: Airline/Operator',
#  'Origin State',
#  'When: Phase of flight',
#  'Conditions: Precipitation',
#  'Remarks',
#  'Wildlife: Size',
#  'Conditions: Sky',
#  'Wildlife: Species',
#  'Pilot warned of birds or wildlife?',
#  'Cost: Total $',
#  'Feet above ground',
#  'Is Aircraft Large?']

# %%
con
# Out:
# ['Record ID',
#  'Wildlife: Number Struck Actual',
#  'Remains of wildlife collected?',
#  'Remains of wildlife sent to Smithsonian',
#  'Number of people injured']

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Remains of wildlife collected?',y='Remains of wildlife sent to Smithsonian',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Remains of wildlife collected?', ylabel='Remains of wildlife sent to Smithsonian'>

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Remains of wildlife sent to Smithsonian',y='Number of people injured', data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Remains of wildlife sent to Smithsonian', ylabel='Number of people injured'>

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='Effect: Impact to flight',y='Number of people injured', data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Effect: Impact to flight', ylabel='Number of people injured'>

# %% [raw]
# sns.regplot(x='Wildlife: Number struck',y='Number of people injured', data=bird_strikes)

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Effect: Indicated Damage',y='Remains of wildlife collected?',hue='Wildlife: Size',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Effect: Indicated Damage', ylabel='Remains of wildlife collected?'>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Effect: Indicated Damage',y='Remains of wildlife sent to Smithsonian',hue='Wildlife: Size',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Effect: Indicated Damage', ylabel='Remains of wildlife sent to Smithsonian'>

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Remains of wildlife sent to Smithsonian',y='Number of people injured',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Remains of wildlife sent to Smithsonian', ylabel='Number of people injured'>

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Remains of wildlife sent to Smithsonian',y='Wildlife: Number Struck Actual',data=bird_strikes)
# Out:
# <AxesSubplot:xlabel='Remains of wildlife sent to Smithsonian', ylabel='Wildlife: Number Struck Actual'>

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=bird_strikes, x='Number of people injured', y='Aircraft: Number of engines?')
# Out:
# <AxesSubplot:xlabel='Number of people injured', ylabel='Aircraft: Number of engines?'>

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=bird_strikes, x='Number of people injured')
# Out:
# <AxesSubplot:xlabel='Number of people injured', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=bird_strikes, x='Remains of wildlife collected?')
# Out:
# <AxesSubplot:xlabel='Remains of wildlife collected?', ylabel='Density'>

# %%
bird_strikes.sample(10)  #random 10 sample
# Out:
#        Record ID Aircraft: Type                       Airport: Name  \
# 1588      238093       Airplane                  KEY WEST INTL ARPT
# 5663      206387       Airplane                MINETA SAN JOSE INTL
# 12007     239407       Airplane                          LOGAN INTL
# 12055     236928       Airplane  EGLIN AFB/NW FLORIDA REGIONAL ARPT
# 6957      214729       Airplane                   INDIANAPOLIS INTL
# 20707     300302       Airplane               GENERAL MITCHELL INTL
# 9399      223229       Airplane                  PORTLAND INTL (OR)
# 21384     303008       Airplane       BIRMINGHAM-SHUTTLESWORTH INTL
# 19076     265310       Airplane                    KANSAS CITY INTL
# 21914     305536       Airplane                        LAGUARDIA NY
#
#       Altitude bin Aircraft: Make/Model Wildlife: Number struck  \
# 1588     < 1000 ft              BE-1900                 2 to 10
# 5663     < 1000 ft                A-320                       1
# ...

# %%
bird_strikes.std()
# Out:
# Record ID                                  38510.453382
# Wildlife: Number Struck Actual                12.793975
# Remains of wildlife collected?                 0.442443
# Remains of wildlife sent to Smithsonian        0.265915
# Number of people injured                       0.050420
# dtype: float64

# %%
bird_strikes.mean()
# Out:
# Record ID                                  253916.085609
# Wildlife: Number Struck Actual                  2.691525
# Remains of wildlife collected?                  0.267079
# Remains of wildlife sent to Smithsonian         0.076571
# Number of people injured                        0.001056
# dtype: float64

# %%
bird_strikes.median()
# Out:
# Record ID                                  248749.0
# Wildlife: Number Struck Actual                  1.0
# Remains of wildlife collected?                  0.0
# Remains of wildlife sent to Smithsonian         0.0
# Number of people injured                        0.0
# dtype: float64

# %%
bird_strikes['When: Phase of flight'].mode()
# Out:
# 0    Approach
# dtype: object

# %%
bird_strikes['Airport: Name'].mode()
# Out:
# 0    DALLAS/FORT WORTH INTL ARPT
# dtype: object

# %%
# early Analysis & Bird Strikes in the US
in_us = bird_strikes[(bird_strikes['Effect: Indicated Damage'] == 'Caused damage') & 
                      (bird_strikes['Aircraft: Airline/Operator'] == 'US AIRWAYS*')][['FlightDate', 'Aircraft: Airline/Operator', 'Effect: Indicated Damage','Cost: Total $']]
print(in_us.head())
print(in_us.count())
# Out:
#         FlightDate Aircraft: Airline/Operator Effect: Indicated Damage  \
# 0    11/23/00 0:00                US AIRWAYS*            Caused damage
# 35    3/22/00 0:00                US AIRWAYS*            Caused damage
# 43     4/8/00 0:00                US AIRWAYS*            Caused damage
# 75    6/11/00 0:00                US AIRWAYS*            Caused damage
# 262    3/9/01 0:00                US AIRWAYS*            Caused damage
#
#     Cost: Total $
# 0          30,736
# 35              0
# 43              0
# 75        211,146
# 262             0
# FlightDate                    65
# Aircraft: Airline/Operator    65
# Effect: Indicated Damage      65
# Cost: Total $                 65
# dtype: int64

# %%
#Top 10 US Airlines in terms of having encountered bird strikes
top_us= bird_strikes[(bird_strikes['Pilot warned of birds or wildlife?'] == 'Y') & 
                      (bird_strikes['Aircraft: Airline/Operator'] == 'US AIRWAYS*')][['Aircraft: Airline/Operator', 'Origin State']]
top_us.head(10)
# Out:
#     Aircraft: Airline/Operator   Origin State
# 118                US AIRWAYS*       Maryland
# 120                US AIRWAYS*        Alabama
# 212                US AIRWAYS*  Massachusetts
# 215                US AIRWAYS*             DC
# 240                US AIRWAYS*             DC
# 242                US AIRWAYS*   Pennsylvania
# 293                US AIRWAYS*        Georgia
# 296                US AIRWAYS*        Florida
# 305                US AIRWAYS*        Georgia
# 339                US AIRWAYS*   Pennsylvania

# %%
#Airports with most incidents of bird strikes – Top 50
top_50 = bird_strikes[(bird_strikes['Effect: Indicated Damage'] == 'Caused damage') & 
                      (bird_strikes['Aircraft: Airline/Operator'] == 'US AIRWAYS*')][['FlightDate', 'Aircraft: Airline/Operator', 'Effect: Indicated Damage']]
top_50.head()
# Out:
#        FlightDate Aircraft: Airline/Operator Effect: Indicated Damage
# 0   11/23/00 0:00                US AIRWAYS*            Caused damage
# 1    7/25/01 0:00          AMERICAN AIRLINES            Caused damage
# 6    8/17/03 0:00                   BUSINESS            Caused damage
# 7     3/1/06 0:00            UNITED AIRLINES            Caused damage
# 11   1/20/00 0:00          AMERICAN AIRLINES            Caused damage

# %%
#Were Pilots Informed? & Prior Warning and Effect of Strike Relation
warnd = bird_strikes[(bird_strikes['Effect: Indicated Damage'] == 'Caused damage') & (bird_strikes['Pilot warned of birds or wildlife?'] == 'Y' ) ][['Aircraft: Airline/Operator','Pilot warned of birds or wildlife?','Effect: Indicated Damage']]
warnd.head()
# Out:
#    Aircraft: Airline/Operator Pilot warned of birds or wildlife?  \
# 1           AMERICAN AIRLINES                                  Y
# 7             UNITED AIRLINES                                  Y
# 36         NORTHWEST AIRLINES                                  Y
# 50                  ATLAS AIR                                  Y
# 67            PRIVATELY OWNED                                  Y
#
#    Effect: Indicated Damage
# 1             Caused damage
# 7             Caused damage
# 36            Caused damage
# 50            Caused damage
# 67            Caused damage

# %%
#Effect of Strike at Different Altitude
altit = bird_strikes[(bird_strikes['Effect: Indicated Damage'] == 'Caused damage') ][['Aircraft: Airline/Operator','Altitude bin','Effect: Indicated Damage','Feet above ground']]
altit.head()
# Out:
#    Aircraft: Airline/Operator Altitude bin Effect: Indicated Damage  \
# 0                 US AIRWAYS*    > 1000 ft            Caused damage
# 1           AMERICAN AIRLINES    < 1000 ft            Caused damage
# 6                    BUSINESS    < 1000 ft            Caused damage
# 7             UNITED AIRLINES    < 1000 ft            Caused damage
# 11          AMERICAN AIRLINES    > 1000 ft            Caused damage
#
#    Feet above ground
# 0              1,500
# 1                  0
# 6                150
# 7                100
# 11             1,700

# %%
# Effect of Bird Strikes & Impact on Flight
impact = bird_strikes[(bird_strikes['Effect: Indicated Damage'] == 'Caused damage') ][['Aircraft: Airline/Operator','Effect: Indicated Damage','Effect: Impact to flight']]
impact.head()
# Out:
#    Aircraft: Airline/Operator Effect: Indicated Damage  \
# 0                 US AIRWAYS*            Caused damage
# 1           AMERICAN AIRLINES            Caused damage
# 6                    BUSINESS            Caused damage
# 7             UNITED AIRLINES            Caused damage
# 11          AMERICAN AIRLINES            Caused damage
#
#    Effect: Impact to flight
# 0          Engine Shut Down
# 1                      None
# 6                     Other
# 7                     Other
# 11                     None
